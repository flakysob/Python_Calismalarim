# %%
class Calisan():
    def __init__(self, isim, maas, departman):
        Calisan.isim = isim
        Calisan.maas = maas
        Calisan.departman = departman

    def bilgileriGoster(self):
        print(
            """
            ---Çalışan Bilgileri---
            İsim : {}
            Maaş : {}
            Departman : {}

            """.format(self.isim,self.maas,self.departman)
        )
    
    def departmanDegistir(self,yenidepartman):
        eskidepartman = self.departman
        self.departman = yenidepartman
        print(eskidepartman, " olan departman bilgisi ",yenidepartman, " olarak değiştirildi.")

# %%
i = input("İsim gir : ")
m = input("Maaş gir : ")
d = input("Hangi departman : ")

isci1 = Calisan(i,m,d)
Calisan.bilgileriGoster(isci1)
# Out:
#             ---Çalışan Bilgileri---
#             İsim : Taha
#             Maaş : 5000
#             Departman : Yazılım

# %%
isci1.departmanDegistir("Amele")
# Out:
# Yazılım  olan departman bilgisi  Amele  olarak değiştirildi.

# %%
#Yönetici sınıfını Calisan sınıfından türetiyoruz.
class Yonetici(Calisan): #Yönetici sınıfı, Calisan sınıfından miras alıyor.
    pass #Bir bloğu sonradan tanımlamak istedğimizde bu ifade kullanılır.

# %%
dir(Yonetici)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bilgileriGoster',
#  'departman',
#  'departmanDegistir',
#  'isim',
#  'maas']

# %%
class Yonetici(Calisan):
    def zam_yap(self,zam):
        eskimaas = self.maas
        self.maas = eskimaas + zam
        print(eskimaas," olan maaş miktarı ", self.maas," olarak güncellendi.")

# %%
i = input("İsim gir : ")
m = int(input("Maaş gir : "))
d = input("Hangi departman : ")

yonetici1 = Yonetici(isim=i,maas=m,departman=d)
yonetici1.bilgileriGoster()
yonetici1.zam_yap(1000)
yonetici1.bilgileriGoster()
# Out:
#             ---Çalışan Bilgileri---
#             İsim : Alex
#             Maaş : 6000
#             Departman : Yönetim
#
#
# 6000  olan maaş miktarı  7000  olarak güncellendi.
#
#             ---Çalışan Bilgileri---
#             İsim : Alex
#             Maaş : 7000
#             Departman : Yönetim

# %%
class Calisan():
    def __init__(self,isim,maas,departman):
        print("Calisan sınıfının init fonksiyonu.")
        self.isim = isim
        self.maas = maas
        self.departman = departman

    def bilgilerigoster(self):
        print("----Çalışan sınıfının bilgileri----")
        print(" İsim : {} \n Maaş : {} \n Depratman : {} \n".format(self.isim,self.maas,self.departman))

    def departmandegistir(self,yeni_departman):
        eski_departman = self.departman
        self.departman = yeni_departman
        print("{} olan departman bilgisi, {} olarak değiştirildi.".format(eski_departman,yeni_departman))

# %%
class Yonetici(Calisan):
